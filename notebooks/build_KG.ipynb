# %%
# %pip install -q networkx pyvis matplotlib neo4j

# %% [markdown]
# # Start `neo4j` before executing this notebook
#
# - Create a directory to persist the database:
# ```bash
# mkdir -p $(pwd)/data/neo4j
# ```
#
# - Run the Neo4j Docker container:
# ```bash
# docker run -d \
#   --name neo4j-local \
#   -p 7474:7474 -p 7687:7687 \
#   -e NEO4J_AUTH=none \
#   -v "$(pwd)/data/neo4j:/data" \
#   neo4j:latest
# ```
#
# - Grant permissions to the data directory:
# ```bash
# sudo chown -R 7474:7474 ./data/neo4j
# ```

# %%
import json
import networkx as nx
from pyvis.network import Network
import pandas as pd
import matplotlib.pyplot as plt
from neo4j import GraphDatabase
from IPython.display import display, HTML
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Load the data
data_path = "../data/raw/graph_documents.json"
with open(data_path, 'r', encoding='utf-8') as f:
    graph_documents = json.load(f)

print(f"Loaded {len(graph_documents)} documents.")
# Out:
# Loaded 604 documents.

# %% [markdown]
# # Config

# %%
class Neo4jLoader:
    def __init__(self, uri, auth):
        try:
            # If auth is None, we don't pass it to the driver
            if auth is None:
                self.driver = GraphDatabase.driver(uri)
            else:
                self.driver = GraphDatabase.driver(uri, auth=auth)
            self.verify_connection()
        except Exception as e:
            print(f"Initialization Error: {e}")
            self.driver = None

    def verify_connection(self):
        try:
            self.driver.verify_connectivity()
            print("Connected to Neo4j successfully.")
        except Exception as e:
            print(f"Failed to connect to Neo4j: {e}")
            print("1. Is the Neo4j database running?")
            print("2. Are the URI and PORT correct? (default: bolt://localhost:7687)")
            print("3. Is the password correct?")
            raise e

    def close(self):
        if self.driver:
            self.driver.close()

    def clear_database(self):
        if not self.driver: return
        with self.driver.session() as session:
            session.run("MATCH (n) DETACH DELETE n")
            print("Database cleared.")

    def load_data(self, documents):
        if not self.driver: return
        with self.driver.session() as session:
            for i, doc in enumerate(documents):

                # Create nodes
                for node in doc['nodes']:
                    # remove "(Phụ Lục ...)" from nodes
                    node['id'] = node['id'].split(' (Phụ Lục')[0].strip()
                    # Sanitize label
                    label = "".join(x for x in node['type'] if x.isalnum() or x == "_").upper()
                    if not label: label = "ENTITY"
                    
                    query = (
                        f"MERGE (n:`{label}` {{id: $id}}) "
                        "SET n.type = $type "
                        "SET n += $properties"
                    )
                    session.run(query, id=node['id'], type=node['type'], properties=node.get('properties', {}))
                
                # Create relationships
                for rel in doc['relationships']:
                    rel_type = "".join(x for x in rel['type'] if x.isalnum() or x == "_").upper()
                    if not rel_type: rel_type = "RELATED_TO"
                    
                    # Clean source/target to match nodes
                    source_id = rel['source'].split(' (Phụ Lục')[0].strip()
                    target_id = rel['target'].split(' (Phụ Lục')[0].strip()

                    query = (
                        "MATCH (a {id: $source}), (b {id: $target}) "
                        f"MERGE (a)-[r:`{rel_type}`]->(b) "
                        "SET r += $properties"
                    )
                    session.run(
                        query, 
                        source=source_id, 
                        target=target_id, 
                        properties=rel.get('properties', {})
                    )
                
                if (i + 1) % 10 == 0:
                    print(f"Processed {i + 1} documents...", end = "\r")

def get_subgraph_from_neo4j(uri, auth, limit=50):
    """Fetches a subgraph from Neo4j into NetworkX for visualization."""
    driver = GraphDatabase.driver(uri, auth=auth)
    G = nx.DiGraph()
    
    query = f"""
    MATCH (n)-[r]->(m)
    RETURN n, r, m
    LIMIT {limit}
    """
    
    try:
        with driver.session() as session:
            result = session.run(query)
            for record in result:
                n = record['n']
                m = record['m']
                r = record['r']
                
                # Add nodes with properties
                G.add_node(n['id'], label=n['id'], title=n['id'], group=n.get('type', 'Entity'), **dict(n))
                G.add_node(m['id'], label=m['id'], title=m['id'], group=m.get('type', 'Entity'), **dict(m))
                
                # Add edge
                G.add_edge(n['id'], m['id'], title=r.type, label=r.type, **dict(r))
    except Exception as e:
        print(f"Error fetching data: {e}")
    finally:
        driver.close()
        
    return G

def visualize_neo4j_subgraph(uri, auth, limit=50, output_file="neo4j_viz.html"):
    G = get_subgraph_from_neo4j(uri, auth, limit)
    
    if G.number_of_nodes() == 0:
        print("No data found or connection failed.")
        return

    print(f"Visualizing subgraph with {G.number_of_nodes()} nodes and {G.number_of_edges()} edges.")

    net = Network(notebook=True, height="600px", width="100%", bgcolor="#222222", font_color="white", cdn_resources='in_line')
    net.from_nx(G)
    net.repulsion(node_distance=150, spring_length=200)
    net.show(output_file)
    return output_file

# ------ Print full schema ------
def print_neo4j_schema(uri, auth):
    driver = GraphDatabase.driver(uri, auth=auth)
    try:
        with driver.session() as session:
            result = session.run("CALL db.schema.visualization()")
            nodes = set()
            relationships = set()
            for record in result:
                for node in record['nodes']:
                    nodes.add(tuple(node.labels))
                for rel in record['relationships']:
                    relationships.add((rel.start_node.labels, rel.type, rel.end_node.labels))
            print("Node Labels:")
            for label in nodes:
                print(f" - {label}")
            print("\nRelationships:")
            for start_labels, rel_type, end_labels in relationships:
                print(f" - ({start_labels})-[:{rel_type}]->({end_labels})")
            # for rel_type in relationships:
                # print(f" - {rel_type}")
    except Exception as e:
        print(f"Error fetching schema: {e}")
    finally:
        driver.close()
        
# ------ Get Statistics ------
def get_neo4j_statistics(uri, auth):
    driver = GraphDatabase.driver(uri, auth=auth)
    stats = {}
    try:
        with driver.session() as session:
            node_count = session.run("MATCH (n) RETURN count(n) AS count").single()["count"]
            rel_count = session.run("MATCH ()-[r]->() RETURN count(r) AS count").single()["count"]
            stats['node_count'] = node_count
            stats['relationship_count'] = rel_count
    except Exception as e:
        print(f"Error fetching statistics: {e}")
    finally:
        driver.close()
    return stats

# ------ Find orphan nodes ------
def find_orphans_neo4j(uri, auth, n=10):
    driver = GraphDatabase.driver(uri, auth=auth)
    query = f"""
    MATCH (n)
    WHERE NOT (n)--()
    RETURN n.id AS id, n.type AS type
    LIMIT {n}
    """
    
    try:
        with driver.session() as session:
            result = session.run(query)
            orphans = [record['id'] for record in result]
            
            # Get count
            count_result = session.run("MATCH (n) WHERE NOT (n)--() RETURN count(n) as count")
            total = count_result.single()['count']
            
            print(f"Total orphan nodes in DB: {total}")
            if orphans:
                print(f"First {n} orphan nodes:")
                for oid in orphans:
                    print(f" - {oid}")
    except Exception as e:
        print(f"Error: {e}")
    finally:
        driver.close()

# ------ Remove orphan nodes ------
def remove_orphans_neo4j(uri, auth):
    driver = GraphDatabase.driver(uri, auth=auth)
    # Cypher query to match nodes with no relationships and delete them
    query = "MATCH (n) WHERE NOT (n)--() DELETE n"
    
    try:
        with driver.session() as session:
            # Check count before
            count_before = session.run("MATCH (n) WHERE NOT (n)--() RETURN count(n) as count").single()['count']
            print(f"Orphans before deletion: {count_before}")
            
            if count_before > 0:
                session.run(query)
                print(f"Successfully deleted {count_before} orphan nodes.")
            else:
                print("No orphan nodes found to delete.")
                
    except Exception as e:
        print(f"Error removing orphans: {e}")
    finally:
        driver.close()
        
# ------ Query function ------
def query(uri, auth, cypher_query):
    driver = GraphDatabase.driver(uri, auth=auth)
    results = []
    try:
        with driver.session() as session:
            result = session.run(cypher_query)
            for record in result:
                results.append(record.data())
    except Exception as e:
        print(f"Error executing query: {e}")
    finally:
        driver.close()
    return results

# %% [markdown]
# # Configuration

# %%
# Neo4j Configuration
URI = os.getenv("Neo4j_URI")
# AUTH = ("neo4j", "password")
AUTH = None

# Initialize and load
# NOTE: Set run_import to True to execute the import. 
# Be careful as this clears the database first.
run_import = True
output_html = "../data/neo4j_subgraph.html"
remove_orphan_nodes = True

# %% [markdown]
# # Main execution

# %%
# ------ Load data into Neo4j -----
print("\n====== Import Data======\n")
if run_import:
    try:
        loader = Neo4jLoader(URI, AUTH)
        if loader.driver:
            loader.clear_database()
            loader.load_data(graph_documents)
            loader.close()
            print("\nImport finished.")
    except Exception:
        print("Import failed due to connection error.")
else:
    print("Skipping import. Set run_import=True to run.")
    
# ------ Get statistics and schema ------
print("\n====== Statistics======\n")
stats = get_neo4j_statistics(URI, AUTH)
print(f"Total Nodes: {stats.get('node_count', 'N/A')}")
print(f"Total Relationships: {stats.get('relationship_count', 'N/A')}")
        
print("\n====== Full Schema======\n")
print_neo4j_schema(URI, AUTH)

# ------ Find and remove orphan nodes ------
if remove_orphan_nodes:
    print("\n====== Remove Orphan Nodes======\n")
    find_orphans_neo4j(URI, AUTH, 5)
    remove_orphans_neo4j(URI, AUTH)

# ------ Visualize ------
print("\n====== Visualize Subgraph======\n")
output_html = visualize_neo4j_subgraph(URI, AUTH, limit=50, output_file=output_html)
# Out:
# ====== Import Data======
#
# Connected to Neo4j successfully.
# Database cleared.
# Processed 600 documents...
# Import finished.
#
# ====== Statistics======
#
# Total Nodes: 927
# Total Relationships: 24452
#
# ====== Full Schema======
#
# Node Labels:
#  - ('DRUG',)
#  - ('CHEMICAL',)
#  - ('PRODUCTION_METHOD',)
#  - ('STANDARD',)
#  - ('TEST_METHOD',)
#  - ('STORAGE_CONDITION',)
#  - ('DISEASE',)
#  - ('ORGANISM',)
#
# Relationships:
#  - (frozenset({'STORAGE_CONDITION'}))-[:HAS_STANDARD]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DRUG'}))-[:PRODUCED_BY]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'DRUG'}))-[:TESTED_BY]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:HAS_STANDARD]->(frozenset({'ORGANISM'}))
#  - (frozenset({'CHEMICAL'}))-[:PRODUCED_BY]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'DISEASE'}))-[:STORED_AT]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:PRODUCED_BY]->(frozenset({'STANDARD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TESTED_BY]->(frozenset({'STANDARD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:STORED_AT]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'ORGANISM'}))-[:REQUIRES]->(frozenset({'DRUG'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TREATS]->(frozenset({'DISEASE'}))
#  - (frozenset({'DISEASE'}))-[:REQUIRES]->(frozenset({'DISEASE'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:CONTAINS]->(frozenset({'STANDARD'}))
#  - (frozenset({'DRUG'}))-[:REQUIRES]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TARGETS]->(frozenset({'STANDARD'}))
#  - (frozenset({'DISEASE'}))-[:HAS_STANDARD]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'TEST_METHOD'}))-[:CONTAINS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'DISEASE'}))-[:TREATS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'ORGANISM'}))-[:CONTAINS]->(frozenset({'DRUG'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:HAS_STANDARD]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'TEST_METHOD'}))-[:PRODUCED_BY]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'ORGANISM'}))-[:TARGETS]->(frozenset({'DRUG'}))
#  - (frozenset({'CHEMICAL'}))-[:REQUIRES]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'STANDARD'}))-[:TARGETS]->(frozenset({'DRUG'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TREATS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:REQUIRES]->(frozenset({'STANDARD'}))
#  - (frozenset({'DISEASE'}))-[:TARGETS]->(frozenset({'DISEASE'}))
#  - (frozenset({'STANDARD'}))-[:TESTED_BY]->(frozenset({'STANDARD'}))
#  - (frozenset({'DISEASE'}))-[:PRODUCED_BY]->(frozenset({'STANDARD'}))
#  - (frozenset({'DISEASE'}))-[:TESTED_BY]->(frozenset({'STANDARD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TREATS]->(frozenset({'STANDARD'}))
#  - (frozenset({'CHEMICAL'}))-[:CONTAINS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'CHEMICAL'}))-[:TARGETS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'ORGANISM'}))-[:TREATS]->(frozenset({'DRUG'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:CONTAINS]->(frozenset({'STANDARD'}))
#  - (frozenset({'CHEMICAL'}))-[:HAS_STANDARD]->(frozenset({'STANDARD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TARGETS]->(frozenset({'STANDARD'}))
#  - (frozenset({'STANDARD'}))-[:STORED_AT]->(frozenset({'DISEASE'}))
#  - (frozenset({'TEST_METHOD'}))-[:TESTED_BY]->(frozenset({'DISEASE'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:PRODUCED_BY]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'TEST_METHOD'}))-[:REQUIRES]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TESTED_BY]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STANDARD'}))-[:HAS_STANDARD]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:PRODUCED_BY]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DISEASE'}))-[:HAS_STANDARD]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'DRUG'}))-[:PRODUCED_BY]->(frozenset({'DISEASE'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TESTED_BY]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DRUG'}))-[:TESTED_BY]->(frozenset({'DISEASE'}))
#  - (frozenset({'DRUG'}))-[:TREATS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'ORGANISM'}))-[:STORED_AT]->(frozenset({'DRUG'}))
#  - (frozenset({'DISEASE'}))-[:STORED_AT]->(frozenset({'DISEASE'}))
#  - (frozenset({'CHEMICAL'}))-[:TREATS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'TEST_METHOD'}))-[:HAS_STANDARD]->(frozenset({'DRUG'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:CONTAINS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DRUG'}))-[:STORED_AT]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TARGETS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'TEST_METHOD'}))-[:TARGETS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'DRUG'}))-[:TESTED_BY]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'DISEASE'}))-[:CONTAINS]->(frozenset({'STANDARD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:REQUIRES]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'CHEMICAL'}))-[:STORED_AT]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:REQUIRES]->(frozenset({'ORGANISM'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TESTED_BY]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STANDARD'}))-[:PRODUCED_BY]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:STORED_AT]->(frozenset({'STANDARD'}))
#  - (frozenset({'DRUG'}))-[:REQUIRES]->(frozenset({'DISEASE'}))
#  - (frozenset({'STANDARD'}))-[:TESTED_BY]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DISEASE'}))-[:PRODUCED_BY]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DISEASE'}))-[:TESTED_BY]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DISEASE'}))-[:TREATS]->(frozenset({'DISEASE'}))
#  - (frozenset({'STANDARD'}))-[:HAS_STANDARD]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:HAS_STANDARD]->(frozenset({'DISEASE'}))
#  - (frozenset({'ORGANISM'}))-[:HAS_STANDARD]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STANDARD'}))-[:CONTAINS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'TEST_METHOD'}))-[:TREATS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TREATS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'ORGANISM'}))-[:TESTED_BY]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DRUG'}))-[:TREATS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:HAS_STANDARD]->(frozenset({'DRUG'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:CONTAINS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TARGETS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:CONTAINS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'CHEMICAL'}))-[:HAS_STANDARD]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DRUG'}))-[:CONTAINS]->(frozenset({'DISEASE'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TARGETS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DRUG'}))-[:TARGETS]->(frozenset({'DISEASE'}))
#  - (frozenset({'CHEMICAL'}))-[:REQUIRES]->(frozenset({'STANDARD'}))
#  - (frozenset({'TEST_METHOD'}))-[:STORED_AT]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TREATS]->(frozenset({'STANDARD'}))
#  - (frozenset({'DISEASE'}))-[:REQUIRES]->(frozenset({'STANDARD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:HAS_STANDARD]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'DISEASE'}))-[:TESTED_BY]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STANDARD'}))-[:PRODUCED_BY]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TREATS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'DISEASE'}))-[:HAS_STANDARD]->(frozenset({'DISEASE'}))
#  - (frozenset({'CHEMICAL'}))-[:TESTED_BY]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'CHEMICAL'}))-[:CONTAINS]->(frozenset({'STANDARD'}))
#  - (frozenset({'CHEMICAL'}))-[:TARGETS]->(frozenset({'STANDARD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:PRODUCED_BY]->(frozenset({'DRUG'}))
#  - (frozenset({'STANDARD'}))-[:CONTAINS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'ORGANISM'}))-[:TESTED_BY]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:CONTAINS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:STORED_AT]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:STORED_AT]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DRUG'}))-[:STORED_AT]->(frozenset({'DISEASE'}))
#  - (frozenset({'DRUG'}))-[:HAS_STANDARD]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:HAS_STANDARD]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'STANDARD'}))-[:TARGETS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'CHEMICAL'}))-[:TREATS]->(frozenset({'STANDARD'}))
#  - (frozenset({'DISEASE'}))-[:TARGETS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'TEST_METHOD'}))-[:TESTED_BY]->(frozenset({'STANDARD'}))
#  - (frozenset({'STANDARD'}))-[:TREATS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:REQUIRES]->(frozenset({'DRUG'}))
#  - (frozenset({'DRUG'}))-[:PRODUCED_BY]->(frozenset({'STANDARD'}))
#  - (frozenset({'STANDARD'}))-[:HAS_STANDARD]->(frozenset({'DISEASE'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:PRODUCED_BY]->(frozenset({'DRUG'}))
#  - (frozenset({'DRUG'}))-[:TESTED_BY]->(frozenset({'STANDARD'}))
#  - (frozenset({'CHEMICAL'}))-[:PRODUCED_BY]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TESTED_BY]->(frozenset({'DRUG'}))
#  - (frozenset({'CHEMICAL'}))-[:REQUIRES]->(frozenset({'ORGANISM'}))
#  - (frozenset({'CHEMICAL'}))-[:STORED_AT]->(frozenset({'STANDARD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TREATS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'STANDARD'}))-[:REQUIRES]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DRUG'}))-[:TREATS]->(frozenset({'DISEASE'}))
#  - (frozenset({'DISEASE'}))-[:REQUIRES]->(frozenset({'ORGANISM'}))
#  - (frozenset({'ORGANISM'}))-[:HAS_STANDARD]->(frozenset({'DRUG'}))
#  - (frozenset({'STANDARD'}))-[:STORED_AT]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'ORGANISM'}))-[:CONTAINS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'ORGANISM'}))-[:TARGETS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STANDARD'}))-[:TESTED_BY]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:CONTAINS]->(frozenset({'DRUG'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TARGETS]->(frozenset({'DRUG'}))
#  - (frozenset({'CHEMICAL'}))-[:CONTAINS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DRUG'}))-[:HAS_STANDARD]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'CHEMICAL'}))-[:TARGETS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'STANDARD'}))-[:TARGETS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:STORED_AT]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:TARGETS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:REQUIRES]->(frozenset({'DRUG'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:CONTAINS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'CHEMICAL'}))-[:REQUIRES]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STANDARD'}))-[:TREATS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:TREATS]->(frozenset({'STANDARD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TARGETS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'DISEASE'}))-[:PRODUCED_BY]->(frozenset({'DRUG'}))
#  - (frozenset({'DISEASE'}))-[:TESTED_BY]->(frozenset({'DRUG'}))
#  - (frozenset({'ORGANISM'}))-[:TREATS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:HAS_STANDARD]->(frozenset({'STANDARD'}))
#  - (frozenset({'STANDARD'}))-[:CONTAINS]->(frozenset({'DISEASE'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TREATS]->(frozenset({'DRUG'}))
#  - (frozenset({'ORGANISM'}))-[:PRODUCED_BY]->(frozenset({'DISEASE'}))
#  - (frozenset({'STANDARD'}))-[:REQUIRES]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'ORGANISM'}))-[:TESTED_BY]->(frozenset({'DISEASE'}))
#  - (frozenset({'CHEMICAL'}))-[:TREATS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DRUG'}))-[:REQUIRES]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'STANDARD'}))-[:STORED_AT]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:CONTAINS]->(frozenset({'DRUG'}))
#  - (frozenset({'CHEMICAL'}))-[:HAS_STANDARD]->(frozenset({'DRUG'}))
#  - (frozenset({'TEST_METHOD'}))-[:TESTED_BY]->(frozenset({'ORGANISM'}))
#  - (frozenset({'CHEMICAL'}))-[:CONTAINS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'ORGANISM'}))-[:STORED_AT]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'CHEMICAL'}))-[:TARGETS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STANDARD'}))-[:PRODUCED_BY]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'DRUG'}))-[:PRODUCED_BY]->(frozenset({'ORGANISM'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:STORED_AT]->(frozenset({'DRUG'}))
#  - (frozenset({'DRUG'}))-[:TESTED_BY]->(frozenset({'ORGANISM'}))
#  - (frozenset({'TEST_METHOD'}))-[:CONTAINS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'TEST_METHOD'}))-[:HAS_STANDARD]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'CHEMICAL'}))-[:STORED_AT]->(frozenset({'ORGANISM'}))
#  - (frozenset({'TEST_METHOD'}))-[:PRODUCED_BY]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'STANDARD'}))-[:CONTAINS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'ORGANISM'}))-[:TESTED_BY]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'DRUG'}))-[:CONTAINS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:CONTAINS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'DRUG'}))-[:TARGETS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:HAS_STANDARD]->(frozenset({'STANDARD'}))
#  - (frozenset({'ORGANISM'}))-[:REQUIRES]->(frozenset({'DISEASE'}))
#  - (frozenset({'CHEMICAL'}))-[:TREATS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'CHEMICAL'}))-[:PRODUCED_BY]->(frozenset({'DRUG'}))
#  - (frozenset({'DRUG'}))-[:REQUIRES]->(frozenset({'ORGANISM'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:STORED_AT]->(frozenset({'DRUG'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:HAS_STANDARD]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'CHEMICAL'}))-[:STORED_AT]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:PRODUCED_BY]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:TREATS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'TEST_METHOD'}))-[:REQUIRES]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TESTED_BY]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:HAS_STANDARD]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DRUG'}))-[:HAS_STANDARD]->(frozenset({'DISEASE'}))
#  - (frozenset({'STANDARD'}))-[:TARGETS]->(frozenset({'DISEASE'}))
#  - (frozenset({'TEST_METHOD'}))-[:CONTAINS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'TEST_METHOD'}))-[:PRODUCED_BY]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:REQUIRES]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'DRUG'}))-[:CONTAINS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'STANDARD'}))-[:TREATS]->(frozenset({'DISEASE'}))
#  - (frozenset({'DRUG'}))-[:STORED_AT]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DRUG'}))-[:TARGETS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'STANDARD'}))-[:HAS_STANDARD]->(frozenset({'STANDARD'}))
#  - (frozenset({'CHEMICAL'}))-[:REQUIRES]->(frozenset({'DRUG'}))
#  - (frozenset({'DRUG'}))-[:TREATS]->(frozenset({'STANDARD'}))
#  - (frozenset({'TEST_METHOD'}))-[:TARGETS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TREATS]->(frozenset({'DRUG'}))
#  - (frozenset({'STANDARD'}))-[:REQUIRES]->(frozenset({'DISEASE'}))
#  - (frozenset({'DRUG'}))-[:HAS_STANDARD]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'DISEASE'}))-[:TARGETS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:REQUIRES]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:HAS_STANDARD]->(frozenset({'ORGANISM'}))
#  - (frozenset({'STANDARD'}))-[:TREATS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:PRODUCED_BY]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'ORGANISM'}))-[:STORED_AT]->(frozenset({'DISEASE'}))
#  - (frozenset({'TEST_METHOD'}))-[:REQUIRES]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TESTED_BY]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'CHEMICAL'}))-[:CONTAINS]->(frozenset({'DRUG'}))
#  - (frozenset({'CHEMICAL'}))-[:TARGETS]->(frozenset({'DRUG'}))
#  - (frozenset({'ORGANISM'}))-[:HAS_STANDARD]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'TEST_METHOD'}))-[:TREATS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'STANDARD'}))-[:REQUIRES]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'STANDARD'}))-[:PRODUCED_BY]->(frozenset({'STANDARD'}))
#  - (frozenset({'STANDARD'}))-[:STORED_AT]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'TEST_METHOD'}))-[:TESTED_BY]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'STANDARD'}))-[:CONTAINS]->(frozenset({'STANDARD'}))
#  - (frozenset({'DRUG'}))-[:PRODUCED_BY]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'ORGANISM'}))-[:TESTED_BY]->(frozenset({'STANDARD'}))
#  - (frozenset({'TEST_METHOD'}))-[:STORED_AT]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'TEST_METHOD'}))-[:TARGETS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:PRODUCED_BY]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'CHEMICAL'}))-[:TREATS]->(frozenset({'DRUG'}))
#  - (frozenset({'DISEASE'}))-[:STORED_AT]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:REQUIRES]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'STANDARD'}))-[:HAS_STANDARD]->(frozenset({'ORGANISM'}))
#  - (frozenset({'ORGANISM'}))-[:PRODUCED_BY]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'CHEMICAL'}))-[:TESTED_BY]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DRUG'}))-[:TESTED_BY]->(frozenset({'DRUG'}))
#  - (frozenset({'TEST_METHOD'}))-[:CONTAINS]->(frozenset({'DISEASE'}))
#  - (frozenset({'DRUG'}))-[:TREATS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'CHEMICAL'}))-[:STORED_AT]->(frozenset({'DRUG'}))
#  - (frozenset({'TEST_METHOD'}))-[:PRODUCED_BY]->(frozenset({'DISEASE'}))
#  - (frozenset({'ORGANISM'}))-[:HAS_STANDARD]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'TEST_METHOD'}))-[:TREATS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:CONTAINS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'DRUG'}))-[:REQUIRES]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:STORED_AT]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TARGETS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:TREATS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:REQUIRES]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STANDARD'}))-[:TESTED_BY]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'DISEASE'}))-[:PRODUCED_BY]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'TEST_METHOD'}))-[:STORED_AT]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'TEST_METHOD'}))-[:CONTAINS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'TEST_METHOD'}))-[:PRODUCED_BY]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'STANDARD'}))-[:PRODUCED_BY]->(frozenset({'ORGANISM'}))
#  - (frozenset({'ORGANISM'}))-[:REQUIRES]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DRUG'}))-[:CONTAINS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'DRUG'}))-[:TARGETS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:PRODUCED_BY]->(frozenset({'DISEASE'}))
#  - (frozenset({'DRUG'}))-[:HAS_STANDARD]->(frozenset({'STANDARD'}))
#  - (frozenset({'TEST_METHOD'}))-[:REQUIRES]->(frozenset({'DISEASE'}))
#  - (frozenset({'STANDARD'}))-[:TARGETS]->(frozenset({'STANDARD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TESTED_BY]->(frozenset({'DISEASE'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TREATS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:CONTAINS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STANDARD'}))-[:CONTAINS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:HAS_STANDARD]->(frozenset({'DRUG'}))
#  - (frozenset({'CHEMICAL'}))-[:HAS_STANDARD]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'CHEMICAL'}))-[:TESTED_BY]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'CHEMICAL'}))-[:PRODUCED_BY]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TARGETS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'DISEASE'}))-[:TARGETS]->(frozenset({'STANDARD'}))
#  - (frozenset({'ORGANISM'}))-[:PRODUCED_BY]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'ORGANISM'}))-[:TESTED_BY]->(frozenset({'ORGANISM'}))
#  - (frozenset({'STANDARD'}))-[:TREATS]->(frozenset({'STANDARD'}))
#  - (frozenset({'ORGANISM'}))-[:CONTAINS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'ORGANISM'}))-[:TARGETS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:STORED_AT]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'STANDARD'}))-[:REQUIRES]->(frozenset({'STANDARD'}))
#  - (frozenset({'TEST_METHOD'}))-[:TARGETS]->(frozenset({'DISEASE'}))
#  - (frozenset({'TEST_METHOD'}))-[:REQUIRES]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TESTED_BY]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'STANDARD'}))-[:PRODUCED_BY]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STANDARD'}))-[:STORED_AT]->(frozenset({'STANDARD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:REQUIRES]->(frozenset({'DISEASE'}))
#  - (frozenset({'ORGANISM'}))-[:REQUIRES]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TESTED_BY]->(frozenset({'DISEASE'}))
#  - (frozenset({'DISEASE'}))-[:HAS_STANDARD]->(frozenset({'DRUG'}))
#  - (frozenset({'DISEASE'}))-[:CONTAINS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'DRUG'}))-[:STORED_AT]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'ORGANISM'}))-[:TREATS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:STORED_AT]->(frozenset({'STANDARD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:STORED_AT]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'ORGANISM'}))-[:HAS_STANDARD]->(frozenset({'DISEASE'}))
#  - (frozenset({'CHEMICAL'}))-[:PRODUCED_BY]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'TEST_METHOD'}))-[:TREATS]->(frozenset({'DISEASE'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:CONTAINS]->(frozenset({'DISEASE'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TARGETS]->(frozenset({'DISEASE'}))
#  - (frozenset({'ORGANISM'}))-[:CONTAINS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'ORGANISM'}))-[:STORED_AT]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'ORGANISM'}))-[:TARGETS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'STANDARD'}))-[:HAS_STANDARD]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'DRUG'}))-[:HAS_STANDARD]->(frozenset({'ORGANISM'}))
#  - (frozenset({'STANDARD'}))-[:TARGETS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'TEST_METHOD'}))-[:STORED_AT]->(frozenset({'DISEASE'}))
#  - (frozenset({'DRUG'}))-[:TREATS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'DISEASE'}))-[:TARGETS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DRUG'}))-[:REQUIRES]->(frozenset({'STANDARD'}))
#  - (frozenset({'TEST_METHOD'}))-[:HAS_STANDARD]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'STANDARD'}))-[:TESTED_BY]->(frozenset({'DRUG'}))
#  - (frozenset({'TEST_METHOD'}))-[:TREATS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TREATS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'DISEASE'}))-[:TESTED_BY]->(frozenset({'DISEASE'}))
#  - (frozenset({'STANDARD'}))-[:TREATS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DISEASE'}))-[:REQUIRES]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'CHEMICAL'}))-[:REQUIRES]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'TEST_METHOD'}))-[:CONTAINS]->(frozenset({'STANDARD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TREATS]->(frozenset({'DISEASE'}))
#  - (frozenset({'CHEMICAL'}))-[:TESTED_BY]->(frozenset({'DISEASE'}))
#  - (frozenset({'ORGANISM'}))-[:TREATS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'TEST_METHOD'}))-[:PRODUCED_BY]->(frozenset({'STANDARD'}))
#  - (frozenset({'STANDARD'}))-[:REQUIRES]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DRUG'}))-[:CONTAINS]->(frozenset({'STANDARD'}))
#  - (frozenset({'TEST_METHOD'}))-[:STORED_AT]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'STANDARD'}))-[:STORED_AT]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DRUG'}))-[:TARGETS]->(frozenset({'STANDARD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TARGETS]->(frozenset({'DRUG'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:STORED_AT]->(frozenset({'DISEASE'}))
#  - (frozenset({'DISEASE'}))-[:TARGETS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'ORGANISM'}))-[:STORED_AT]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:HAS_STANDARD]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'ORGANISM'}))-[:PRODUCED_BY]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'DISEASE'}))-[:STORED_AT]->(frozenset({'ORGANISM'}))
#  - (frozenset({'TEST_METHOD'}))-[:HAS_STANDARD]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'STANDARD'}))-[:PRODUCED_BY]->(frozenset({'DRUG'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:PRODUCED_BY]->(frozenset({'STANDARD'}))
#  - (frozenset({'TEST_METHOD'}))-[:REQUIRES]->(frozenset({'STANDARD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TESTED_BY]->(frozenset({'STANDARD'}))
#  - (frozenset({'STANDARD'}))-[:STORED_AT]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'TEST_METHOD'}))-[:TESTED_BY]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STANDARD'}))-[:CONTAINS]->(frozenset({'DRUG'}))
#  - (frozenset({'CHEMICAL'}))-[:PRODUCED_BY]->(frozenset({'DISEASE'}))
#  - (frozenset({'ORGANISM'}))-[:TESTED_BY]->(frozenset({'DRUG'}))
#  - (frozenset({'DISEASE'}))-[:CONTAINS]->(frozenset({'DRUG'}))
#  - (frozenset({'DRUG'}))-[:PRODUCED_BY]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'DRUG'}))-[:TESTED_BY]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'DRUG'}))-[:STORED_AT]->(frozenset({'STANDARD'}))
#  - (frozenset({'ORGANISM'}))-[:CONTAINS]->(frozenset({'DISEASE'}))
#  - (frozenset({'ORGANISM'}))-[:TARGETS]->(frozenset({'DISEASE'}))
#  - (frozenset({'ORGANISM'}))-[:REQUIRES]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'DISEASE'}))-[:STORED_AT]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'TEST_METHOD'}))-[:TARGETS]->(frozenset({'STANDARD'}))
#  - (frozenset({'TEST_METHOD'}))-[:CONTAINS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:HAS_STANDARD]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'CHEMICAL'}))-[:STORED_AT]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'TEST_METHOD'}))-[:PRODUCED_BY]->(frozenset({'ORGANISM'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:REQUIRES]->(frozenset({'STANDARD'}))
#  - (frozenset({'DRUG'}))-[:CONTAINS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DRUG'}))-[:TARGETS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'CHEMICAL'}))-[:REQUIRES]->(frozenset({'DISEASE'}))
#  - (frozenset({'ORGANISM'}))-[:CONTAINS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'ORGANISM'}))-[:TARGETS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'ORGANISM'}))-[:TREATS]->(frozenset({'DISEASE'}))
#  - (frozenset({'DRUG'}))-[:REQUIRES]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'ORGANISM'}))-[:HAS_STANDARD]->(frozenset({'STANDARD'}))
#  - (frozenset({'DISEASE'}))-[:REQUIRES]->(frozenset({'DRUG'}))
#  - (frozenset({'STANDARD'}))-[:TARGETS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'TEST_METHOD'}))-[:TREATS]->(frozenset({'STANDARD'}))
#  - (frozenset({'DISEASE'}))-[:TREATS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:HAS_STANDARD]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:PRODUCED_BY]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TESTED_BY]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'CHEMICAL'}))-[:CONTAINS]->(frozenset({'DISEASE'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:PRODUCED_BY]->(frozenset({'ORGANISM'}))
#  - (frozenset({'TEST_METHOD'}))-[:REQUIRES]->(frozenset({'ORGANISM'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TESTED_BY]->(frozenset({'ORGANISM'}))
#  - (frozenset({'CHEMICAL'}))-[:TARGETS]->(frozenset({'DISEASE'}))
#  - (frozenset({'TEST_METHOD'}))-[:STORED_AT]->(frozenset({'STANDARD'}))
#  - (frozenset({'DRUG'}))-[:HAS_STANDARD]->(frozenset({'DRUG'}))
#  - (frozenset({'DRUG'}))-[:CONTAINS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'DRUG'}))-[:TARGETS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'ORGANISM'}))-[:TREATS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'DISEASE'}))-[:TARGETS]->(frozenset({'DRUG'}))
#  - (frozenset({'TEST_METHOD'}))-[:HAS_STANDARD]->(frozenset({'DISEASE'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:CONTAINS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TARGETS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'STANDARD'}))-[:TREATS]->(frozenset({'DRUG'}))
#  - (frozenset({'DRUG'}))-[:STORED_AT]->(frozenset({'ORGANISM'}))
#  - (frozenset({'ORGANISM'}))-[:PRODUCED_BY]->(frozenset({'STANDARD'}))
#  - (frozenset({'CHEMICAL'}))-[:TESTED_BY]->(frozenset({'STANDARD'}))
#  - (frozenset({'ORGANISM'}))-[:STORED_AT]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'TEST_METHOD'}))-[:TARGETS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'STANDARD'}))-[:REQUIRES]->(frozenset({'DRUG'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:REQUIRES]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'CHEMICAL'}))-[:TREATS]->(frozenset({'DISEASE'}))
#  - (frozenset({'DISEASE'}))-[:HAS_STANDARD]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STANDARD'}))-[:TESTED_BY]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:PRODUCED_BY]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:TESTED_BY]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'STANDARD'}))-[:STORED_AT]->(frozenset({'DRUG'}))
#  - (frozenset({'TEST_METHOD'}))-[:TESTED_BY]->(frozenset({'DRUG'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:REQUIRES]->(frozenset({'ORGANISM'}))
#  - (frozenset({'TEST_METHOD'}))-[:HAS_STANDARD]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:PRODUCED_BY]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:STORED_AT]->(frozenset({'STANDARD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TESTED_BY]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TREATS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DRUG'}))-[:PRODUCED_BY]->(frozenset({'DRUG'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:HAS_STANDARD]->(frozenset({'DISEASE'}))
#  - (frozenset({'CHEMICAL'}))-[:STORED_AT]->(frozenset({'DISEASE'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:CONTAINS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'CHEMICAL'}))-[:HAS_STANDARD]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'ORGANISM'}))-[:HAS_STANDARD]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DRUG'}))-[:STORED_AT]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'TEST_METHOD'}))-[:TREATS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DISEASE'}))-[:STORED_AT]->(frozenset({'DRUG'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TARGETS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'ORGANISM'}))-[:REQUIRES]->(frozenset({'STANDARD'}))
#  - (frozenset({'CHEMICAL'}))-[:PRODUCED_BY]->(frozenset({'STANDARD'}))
#  - (frozenset({'TEST_METHOD'}))-[:STORED_AT]->(frozenset({'ORGANISM'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:HAS_STANDARD]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:REQUIRES]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'STANDARD'}))-[:HAS_STANDARD]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STANDARD'}))-[:TESTED_BY]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:PRODUCED_BY]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'DRUG'}))-[:REQUIRES]->(frozenset({'DRUG'}))
#  - (frozenset({'ORGANISM'}))-[:CONTAINS]->(frozenset({'STANDARD'}))
#  - (frozenset({'DISEASE'}))-[:TESTED_BY]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'DRUG'}))-[:TREATS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'ORGANISM'}))-[:TARGETS]->(frozenset({'STANDARD'}))
#  - (frozenset({'DISEASE'}))-[:TREATS]->(frozenset({'DRUG'}))
#  - (frozenset({'ORGANISM'}))-[:PRODUCED_BY]->(frozenset({'ORGANISM'}))
#  - (frozenset({'CHEMICAL'}))-[:TESTED_BY]->(frozenset({'ORGANISM'}))
#  - (frozenset({'TEST_METHOD'}))-[:CONTAINS]->(frozenset({'DRUG'}))
#  - (frozenset({'DISEASE'}))-[:CONTAINS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:CONTAINS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'TEST_METHOD'}))-[:PRODUCED_BY]->(frozenset({'DRUG'}))
#  - (frozenset({'CHEMICAL'}))-[:HAS_STANDARD]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:STORED_AT]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TARGETS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'DRUG'}))-[:CONTAINS]->(frozenset({'DRUG'}))
#  - (frozenset({'DRUG'}))-[:TARGETS]->(frozenset({'DRUG'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:STORED_AT]->(frozenset({'ORGANISM'}))
#  - (frozenset({'ORGANISM'}))-[:TREATS]->(frozenset({'STANDARD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:PRODUCED_BY]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'STANDARD'}))-[:CONTAINS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:PRODUCED_BY]->(frozenset({'DISEASE'}))
#  - (frozenset({'ORGANISM'}))-[:PRODUCED_BY]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'ORGANISM'}))-[:REQUIRES]->(frozenset({'ORGANISM'}))
#  - (frozenset({'CHEMICAL'}))-[:REQUIRES]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'ORGANISM'}))-[:TESTED_BY]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'ORGANISM'}))-[:STORED_AT]->(frozenset({'STANDARD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TREATS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:REQUIRES]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'TEST_METHOD'}))-[:REQUIRES]->(frozenset({'DRUG'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TESTED_BY]->(frozenset({'DRUG'}))
#  - (frozenset({'DISEASE'}))-[:CONTAINS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'CHEMICAL'}))-[:PRODUCED_BY]->(frozenset({'ORGANISM'}))
#  - (frozenset({'TEST_METHOD'}))-[:TARGETS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'TEST_METHOD'}))-[:HAS_STANDARD]->(frozenset({'STANDARD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:STORED_AT]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:REQUIRES]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'ORGANISM'}))-[:CONTAINS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'DRUG'}))-[:STORED_AT]->(frozenset({'DRUG'}))
#  - (frozenset({'CHEMICAL'}))-[:CONTAINS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:PRODUCED_BY]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'CHEMICAL'}))-[:TARGETS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'ORGANISM'}))-[:TARGETS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TESTED_BY]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'TEST_METHOD'}))-[:TARGETS]->(frozenset({'DRUG'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:REQUIRES]->(frozenset({'DISEASE'}))
#  - (frozenset({'ORGANISM'}))-[:REQUIRES]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STANDARD'}))-[:TESTED_BY]->(frozenset({'DISEASE'}))
#  - (frozenset({'ORGANISM'}))-[:HAS_STANDARD]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'DISEASE'}))-[:PRODUCED_BY]->(frozenset({'DISEASE'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:CONTAINS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'STANDARD'}))-[:HAS_STANDARD]->(frozenset({'DRUG'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TARGETS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:HAS_STANDARD]->(frozenset({'STANDARD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TREATS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:REQUIRES]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'ORGANISM'}))-[:TREATS]->(frozenset({'ORGANISM'}))
#  - (frozenset({'CHEMICAL'}))-[:TREATS]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DRUG'}))-[:TREATS]->(frozenset({'DRUG'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:CONTAINS]->(frozenset({'DISEASE'}))
#  - (frozenset({'CHEMICAL'}))-[:HAS_STANDARD]->(frozenset({'DISEASE'}))
#  - (frozenset({'TEST_METHOD'}))-[:TESTED_BY]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'TEST_METHOD'}))-[:TREATS]->(frozenset({'DRUG'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:TARGETS]->(frozenset({'DISEASE'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:REQUIRES]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'DRUG'}))-[:HAS_STANDARD]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'STANDARD'}))-[:TARGETS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'DRUG'}))-[:PRODUCED_BY]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:PRODUCED_BY]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'DRUG'}))-[:TESTED_BY]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'DISEASE'}))-[:TESTED_BY]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'CHEMICAL'}))-[:CONTAINS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'CHEMICAL'}))-[:STORED_AT]->(frozenset({'PRODUCTION_METHOD'}))
#  - (frozenset({'ORGANISM'}))-[:STORED_AT]->(frozenset({'ORGANISM'}))
#  - (frozenset({'CHEMICAL'}))-[:TARGETS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:TREATS]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'STANDARD'}))-[:TREATS]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'CHEMICAL'}))-[:TESTED_BY]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'TEST_METHOD'}))-[:STORED_AT]->(frozenset({'DRUG'}))
#  - (frozenset({'TEST_METHOD'}))-[:HAS_STANDARD]->(frozenset({'ORGANISM'}))
#  - (frozenset({'STANDARD'}))-[:PRODUCED_BY]->(frozenset({'DISEASE'}))
#  - (frozenset({'CHEMICAL'}))-[:HAS_STANDARD]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'STANDARD'}))-[:REQUIRES]->(frozenset({'CHEMICAL'}))
#  - (frozenset({'PRODUCTION_METHOD'}))-[:STORED_AT]->(frozenset({'STORAGE_CONDITION'}))
#  - (frozenset({'ORGANISM'}))-[:PRODUCED_BY]->(frozenset({'DRUG'}))
#  - (frozenset({'CHEMICAL'}))-[:TESTED_BY]->(frozenset({'DRUG'}))
#  - (frozenset({'DISEASE'}))-[:CONTAINS]->(frozenset({'DISEASE'}))
#  - (frozenset({'CHEMICAL'}))-[:TREATS]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'TEST_METHOD'}))-[:TESTED_BY]->(frozenset({'TEST_METHOD'}))
#  - (frozenset({'STORAGE_CONDITION'}))-[:STORED_AT]->(frozenset({'DISEASE'}))
#  - (frozenset({'DISEASE'}))-[:TREATS]->(frozenset({'PRODUCTION_METHOD'}))
#
# ====== Remove Orphan Nodes======
#
# Total orphan nodes in DB: 84
# First 5 orphan nodes:
#  - Kf
#  - Nmsl
#  - Rickettsia
#  - Insulin
#  - Glutaraldehyd
# Orphans before deletion: 84
# Successfully deleted 84 orphan nodes.
#
# ====== Visualize Subgraph======
#
# Visualizing subgraph with 4 nodes and 5 edges.
# ../data/neo4j_subgraph.html
